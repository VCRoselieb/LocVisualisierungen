# %%
# import libraries
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image, ImageDraw
from mpl_toolkits.mplot3d import Axes3D

# %%
#read in the data
data = pd.read_csv(os.getcwd()+ "\logs\VGG19_XXXS\Cifar10\VGG19_XXXS_bs8_e20_id0.csv",sep= ';')

# get relevant columns
columns= []
index = data.columns
for ins in index:
    if 'train' in ins:
        if 'training' not in ins: # to be improved
            if 'classifier-6' not in ins:
                columns.append(ins)

print(columns)  
name = pd.read_csv(os.getcwd()+ "\logs\VGG19_XXXS\Cifar10\VGG19_XXXS_bs8_e20_id0.csv" ,sep= ';',usecols=columns)

name.head()
# Out:
# ['train-saturation_classifier-2', 'train-saturation_features-0', 'train-saturation_features-10', 'train-saturation_features-14', 'train-saturation_features-17', 'train-saturation_features-20', 'train-saturation_features-23', 'train-saturation_features-27', 'train-saturation_features-3', 'train-saturation_features-30', 'train-saturation_features-33', 'train-saturation_features-36', 'train-saturation_features-40', 'train-saturation_features-43', 'train-saturation_features-46', 'train-saturation_features-49', 'train-saturation_features-7']
#    train-saturation_classifier-2  train-saturation_features-0  \
# 0                          37.50                         75.0
# 1                          43.75                         75.0
# 2                          56.25                         75.0
# 3                          56.25                         75.0
# 4                          56.25                         75.0
#
# ...

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

xs = name['train-saturation_classifier-2']
ys = name['train-saturation_features-0']
zs = name['train-saturation_features-10']
ax.scatter(xs, ys, zs, s=50, alpha=0.6, edgecolors='w')

# ax.set_xlabel('Residual Sugar')
# ax.set_ylabel('Fixed Acidity')
# ax.set_zlabel('Alcohol')

plt.show()

# %%
# initialize list of lists 
data = [[1, 2,3], [2, 4, 6], [3, 6, 9]] 
  
# Create the pandas DataFrame 
df = pd.DataFrame(data, columns = ['Epoche', 'Age', 'JJJ']) 
  
# print dataframe. 
df 


new_row = pd.DataFrame(df.iloc[0])
new_row
# Out:
#         0
# Epoche  1
# Age     2
# JJJ     3

# %%
print(df.iloc[0])

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

xs = df['Name']
ys = df.iloc[0]
# zs = df['JJJ']
ax.scatter(xs, ys, zs, s=50, alpha=0.6, edgecolors='w')

ax.set_xlabel('Epoche')
# ax.set_ylabel('Fixed Acidity')
# ax.set_zlabel('Alcohol')

plt.show()
# Out:
# Name    1
# Age     2
# JJJ     3
# Name: 0, dtype: int64

# %%
# style
plt.style.use('seaborn-darkgrid')
 
# create a color palette
palette = plt.get_cmap('Set1')
 
# multiple line plot
num=0
for column in df.drop('Name', axis=1):
    num = num +1
    plt.plot(df['Name'], df[column], marker='', color=palette(num), linewidth=1, alpha=0.9, label=column)
 
# Add legend
plt.legend(loc=2, ncol=2)
 
# Add titles
plt.title("A (bad) Spaghetti plot", loc='left', fontsize=12, fontweight=0, color='orange')
plt.xlabel("Time")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')
